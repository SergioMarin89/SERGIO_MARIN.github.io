# %% [markdown]
# # Scraping the web with Python.
#
# ## BeautifulSoup

# %% [markdown]
#  - urllib es la libraría que nos permite acceder a información en la web y a solicitar acceso mediante request.
#  - HTML arroja data estructurada y data no estrcturada.
#  - BeautifulSoup analiza y extrae la data estructurada que nos fue entregada en la respuesta del request.
#
#  **web site BeautifulSoup.**
#  https://www.crummy.com/software/BeautifulSoup/bs4/doc/#problems-after-installation

# %%
# Importar paquetes necesarios para el scraping.

import requests
from bs4 import BeautifulSoup

# %%
# Especificar la url

url = 'https://es.wikipedia.org/wiki/Dan_Brown'

# %%
# Enviar y recibir respuesta a la solicitud de acceso

r = requests.get(url)

# %%
# Extraer la respuesta en HTML

html_doc = r.text

print(html_doc)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="es" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Dan Brown - Wikipedia, la enciclopedia libre</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Dan_Brown","wgTitle":"Dan Brown","wgCurRevisionId":107240258,"wgRevisionId":107240258,"wgArticleId":41826,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Artículos que necesitan referencias adicionales","Wikipedia:Referenciar (aún sin clasificar)","Personas vivas","Wikipedia:Control de autoridades con 15 elementos","Wikipedia:Artículos con identificadores VIAF","Wikipedia:Artículos con identificadores ISNI","Wikipedia:Artículos con identificadores BNE","Wikipedia:Artículos con identificadores BNF","Wikipedia:Artículos con identificadores CANTIC","Wikipedia:Artículos con identificadores GND","Wikipedia:Artículos con identificadores LCCN","Wikipedia:Artículos con identificadores SNAC","Wikipedia:Artículos con identificadores SELIBR","Wikipedia:Artículos con identificadores BIBSYS","Wikipedia:Artículos con identificadores SBN","Wikipedia:Artículos con identificadores Open Library","Wikipedia:Referenciar literatura","Hombres","Nacidos en 1964","Escritores de Estados Unidos","Agnósticos","Escritores en inglés","Escritores de suspenso"],"wgBreakFrames":false,"wgPageContentLanguage":"es","wgPageContentModel":"wikitext","wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgMonthNamesShort":["","ene","feb","mar","abr","may","jun","jul","ago","sep","oct","nov","dic"],"wgRelevantPageName":"Dan_Brown","wgRelevantArticleId":41826,"wgRequestId":"WuhlCwpAADgAAAMs6LcAAADM","wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"es","wgMFExpandAllSectionsUserOption":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"español","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgWikibaseItemId":"Q7345","wgScoreNoteLanguages":{"arabic":"العربية","catalan":"català","deutsch":"Deutsch","english":"English","espanol":"español","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"português","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":false,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true});mw.loader.state({"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"re ...
# });mw.loader.implement("user.tokens@1dqfd7l",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });mw.loader.load(["ext.cite.a11y","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.toc","mediawiki.searchSuggest","ext.gadget.a-commons-directo","ext.gadget.refToolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.compactlinks","ext.uls.interface","ext.3d","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=es&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=es&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=es&amp;modules=ext.gadget.imagenesinfobox&amp;only=styles&amp;skin=vector"/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=es&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.32.0-wmf.1"/>
# <meta name="referrer" content="origin"/>
# <meta name="referrer" content="origin-when-crossorigin"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/8/8b/Dan_Brown_bookjacket_cropped.jpg"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/es.m.wikipedia.org/wiki/Dan_Brown"/>
# <link rel="alternate" type="application/x-wiki" title="Editar" href="/w/index.php?title=Dan_Brown&amp;action=edit"/>
# <link rel="edit" title="Editar" href="/w/index.php?title=Dan_Brown&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (es)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//es.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="license" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://es.wikipedia.org/wiki/Dan_Brown"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# <!--[if lt IE 9]><script src="/w/load.php?debug=false&amp;lang=es&amp;modules=html5shiv&amp;only=scripts&amp;skin=vector&amp;sync=1"></script><![endif]-->
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Dan_Brown rootpage-Dan_Brown skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
# 			<div id="siteNotice" class="mw-body-content"><!-- CentralNotice --></div><div class="mw-indicators mw-body-content">
# </div>
# <h1 id="firstHeading" class="firstHeading" lang="es">Dan Brown</h1>			<div id="bodyContent" class="mw-body-content">
# 				<div id="siteSub" class="noprint">De Wikipedia, la enciclopedia libre</div>				<div id="contentSub"></div>
# 								<div id="jump-to-nav" class="mw-jump">
# 					Saltar a:					<a href="#mw-head">navegación</a>, 					<a href="#p-search">búsqueda</a>
# 				</div>
# 				<div id="mw-content-text" lang="es" dir="ltr" class="mw-content-ltr"><div class="mw-parser-output"><table style="" class="noprint plainlinks ambox ambox-style">
# <tr>
# <td class="ambox-image">
# <div style="width:50px;"><img alt="Commons-emblem-question book yellow.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Commons-emblem-question_book_yellow.svg/45px-Commons-emblem-question_book_yellow.svg.png" width="45" height="45" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Commons-emblem-question_book_yellow.svg/68px-Commons-emblem-question_book_yellow.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Commons-emblem-question_book_yellow.svg/90px-Commons-emblem-question_book_yellow.svg.png 2x" data-file-width="48" data-file-height="48" /></div>
# </td>
# <td class="ambox-text">Este artículo tiene <a href="/wiki/Wikipedia:Referencias" title="Wikipedia:Referencias">referencias</a>, pero necesita más para complementar su <a href="/wiki/Wikipedia:Verificabilidad" title="Wikipedia:Verificabilidad">verificabilidad</a>.<br />
# <span style="font-size:88%">Puedes colaborar agregando referencias a <a href="/wiki/Wikipedia:Fuentes_fiables" title="Wikipedia:Fuentes fiables">fuentes fiables</a> como se indica <a href="/wiki/Ayuda:C%C3%B3mo_referenciar" title="Ayuda:Cómo referenciar">aquí</a>. El material sin fuentes fiables podría ser <a href="/wiki/Wikipedia:Wikipedia_no_es_una_fuente_primaria" title="Wikipedia:Wikipedia no es una fuente primaria">cuestionado y eliminado</a>.</span><br />
# <span style="font-size:88%">Este aviso fue puesto el 23 de abril de 2018.</span></td>
# </tr>
# </table>
# <table class="infobox biography vcard" style="width:22.7em; line-height: 1.4em; text-align:left; padding:.23em;">
# <tr>
# <th colspan="3" class="cabecera libro" style="text-align:center;background-color:transparent;color:black;background-color:#4c6099;color:#FFF;">Dan Brown</th>
# </tr>
# <tr>
# <td colspan="3" style="text-align:center;padding:0.2em; line-height:1.3em; vertical-align:middle;;"><a href="/wiki/Archivo:Dan_Brown_bookjacket_cropped.jpg" class="image"><img alt="Dan Brown bookjacket cropped.jpg" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Dan_Brown_bookjacket_cropped.jpg/220px-Dan_Brown_bookjacket_cropped.jpg" width="220" height="308" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Dan_Brown_bookjacket_cropped.jpg/330px-Dan_Brown_bookjacket_cropped.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Dan_Brown_bookjacket_cropped.jpg/440px-Dan_Brown_bookjacket_cropped.jpg 2x" data-file-width="597" data-file-height="835" /></a></td>
# </tr>
# <tr>
# <th colspan="3" style="text-align:center;background-color:#4c6099;color:#FFF;">Información personal</th>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Nombre de nacimiento</th>
# <td colspan="2" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;">Daniel Brown</td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Nacimiento</th>
# <td colspan="2" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;"><a href="/wiki/22_de_junio" title="22 de junio">22 de junio</a> de <a href="/wiki/1964" title="1964">1964</a> (53&#160;años)<br />
# <a href="/wiki/Exeter_(Nuevo_Hampshire)" title="Exeter (Nuevo Hampshire)">Exeter</a>, <a href="/wiki/Nuevo_Hampshire" title="Nuevo Hampshire">Nuevo Hampshire</a>,<br />
# <span class="flagicon"><img alt="Bandera de Estados Unidos" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Flag_of_the_United_States.svg/20px-Flag_of_the_United_States.svg.png" title="Bandera de Estados Unidos" width="20" height="11" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Flag_of_the_United_States.svg/30px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Flag_of_the_United_States.svg/40px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650" /></span> <a href="/wiki/Estados_Unidos" title="Estados Unidos">Estados Unidos</a></td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Nacionalidad</th>
# <td colspan="2" class="category" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;"><a href="/wiki/Estados_Unidos" title="Estados Unidos">Estadounidense</a> <a href="https://www.wikidata.org/wiki/Q7345?uselang=es#P27" title="Ver y modificar los datos en Wikidata"><img alt="Ver y modificar los datos en Wikidata" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" width="10" height="10" style="vertical-align: baseline" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" data-file-width="600" data-file-height="600" /></a></td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Lengua materna</th>
# <td colspan="2" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;"><a href="/wiki/Idioma_ingl%C3%A9s" title="Idioma inglés">Inglés</a> <a href="https://www.wikidata.org/wiki/Q7345?uselang=es#P103" title="Ver y modificar los datos en Wikidata"><img alt="Ver y modificar los datos en Wikidata" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" width="10" height="10" style="vertical-align: baseline" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" data-file-width="600" data-file-height="600" /></a></td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Religión</th>
# <td colspan="2" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;"><a href="/wiki/Agnosticismo" title="Agnosticismo">Agnosticismo</a> <a href="https://www.wikidata.org/wiki/Q7345?uselang=es#P140" title="Ver y modificar los datos en Wikidata"><img alt="Ver y modificar los datos en Wikidata" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" width="10" height="10" style="vertical-align: baseline" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" data-file-width="600" data-file-height="600" /></a></td>
# </tr>
# <tr>
# <th colspan="3" style="text-align:center;background-color:#4c6099;color:#FFF;">Familia</th>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Cónyuge</th>
# <td colspan="2" class="plainlist" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;">Blythe Brown</td>
# </tr>
# <tr>
# <th colspan="3" style="text-align:center;background-color:#4c6099;color:#FFF;">Educación</th>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Alma máter</th>
# <td colspan="2" class="plainlist" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;">
# <ul>
# <li><a href="/wiki/Amherst_College" title="Amherst College">Amherst College</a></li>
# <li><a href="/wiki/Phillips_Exeter_Academy" title="Phillips Exeter Academy">Phillips Exeter Academy</a> <a href="https://www.wikidata.org/wiki/Q7345?uselang=es#P69" title="Ver y modificar los datos en Wikidata"><img alt="Ver y modificar los datos en Wikidata" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" width="10" height="10" style="vertical-align: baseline" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" data-file-width="600" data-file-height="600" /></a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th colspan="3" style="text-align:center;background-color:#4c6099;color:#FFF;">Información profesional</th>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Ocupación</th>
# <td colspan="2" class="role" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;">Escritor</td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Años activo</th>
# <td colspan="2" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;">desde 1998</td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Género</th>
# <td colspan="2" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;"><a href="/wiki/Novela" title="Novela">Novela</a></td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Obras notables</th>
# <td colspan="2" class="plainlist" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;">
# <ul>
# <li><i><a href="/wiki/La_fortaleza_digital" title="La fortaleza digital">La fortaleza digital</a></i></li>
# <li><i><a href="/wiki/La_conspiraci%C3%B3n" title="La conspiración">La conspiración</a></i></li>
# <li><i><a href="/wiki/%C3%81ngeles_y_demonios_(novela)" title="Ángeles y demonios (novela)">Ángeles y demonios</a></i></li>
# <li><i><a href="/wiki/El_c%C3%B3digo_Da_Vinci" title="El código Da Vinci">El código Da Vinci</a></i></li>
# <li><i><a href="/wiki/El_s%C3%ADmbolo_perdido" title="El símbolo perdido">El símbolo perdido</a></i></li>
# <li><i><a href="/wiki/Inferno_(novela_de_Dan_Brown)" title="Inferno (novela de Dan Brown)">Inferno</a></i></li>
# <li><i><a href="/wiki/Origen_(novela_de_Dan_Brown)" title="Origen (novela de Dan Brown)">Origen</a></i> <a href="https://www.wikidata.org/wiki/Q7345?uselang=es#P800" title="Ver y modificar los datos en Wikidata"><img alt="Ver y modificar los datos en Wikidata" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" width="10" height="10" style="vertical-align: baseline" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" data-file-width="600" data-file-height="600" /></a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Distinciones</th>
# <td colspan="2" class="plainlist" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;">
# <ul>
# <li>Crimezone Thriller Awards&#160;<small>(2004)</small></li>
# <li>Humo's Gouden Bladwijzer&#160;<small>(2005)</small> <a href="https://www.wikidata.org/wiki/Q7345?uselang=es#P166" title="Ver y modificar los datos en Wikidata"><img alt="Ver y modificar los datos en Wikidata" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" width="10" height="10" style="vertical-align: baseline" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" data-file-width="600" data-file-height="600" /></a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Firma</th>
# <td colspan="2" class="biography vcard" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;"><a href="/wiki/Archivo:Dan_Brown%27s_signature.svg" class="image"><img alt="Dan Brown's signature.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Dan_Brown%27s_signature.svg/149px-Dan_Brown%27s_signature.svg.png" width="149" height="80" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Dan_Brown%27s_signature.svg/223px-Dan_Brown%27s_signature.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Dan_Brown%27s_signature.svg/297px-Dan_Brown%27s_signature.svg.png 2x" data-file-width="250" data-file-height="135" /></a></td>
# </tr>
# <tr>
# <th colspan="3" style="text-align:center;background-color:#4c6099;color:#FFF;">Web</th>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Sitio web</th>
# <td colspan="2" class="plainlinks" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;">
# <div style="width:14.66em;overflow:hidden;text-overflow:ellipsis;white-space: nowrap;"><a rel="nofollow" class="external text" href="http://www.danbrown.com/">www.danbrown.com</a> <a href="https://www.wikidata.org/wiki/Q7345?uselang=es#P856" title="Ver y modificar los datos en Wikidata"><img alt="Ver y modificar los datos en Wikidata" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" width="10" height="10" style="vertical-align: baseline" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" data-file-width="600" data-file-height="600" /></a></div>
# </td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Facebook</th>
# <td colspan="2" class="plainlinks" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;"><a rel="nofollow" class="external text" href="https://www.facebook.com/DanBrown">DanBrown</a> <a href="https://www.wikidata.org/wiki/Q7345?uselang=es#P2013" title="Ver y modificar los datos en Wikidata"><img alt="Ver y modificar los datos en Wikidata" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" width="10" height="10" style="vertical-align: baseline" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" data-file-width="600" data-file-height="600" /></a></td>
# </tr>
# <tr>
# <th scope="row" style="text-align:left;width:33%;">Twitter</th>
# <td colspan="2" class="plainlinks" style="padding:0.2em; line-height:1.3em; vertical-align:middle;;"><a rel="nofollow" class="external text" href="https://twitter.com/AuthorDanBrown">AuthorDanBrown</a> <a href="https://www.wikidata.org/wiki/Q7345?uselang=es#P2002" title="Ver y modificar los datos en Wikidata"><img alt="Ver y modificar los datos en Wikidata" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" width="10" height="10" style="vertical-align: baseline" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" data-file-width="600" data-file-height="600" /></a></td>
# </tr>
# <tr>
# <td colspan="3" style="text-align:left;"><small>[<span class="plainlinks"><a href="https://www.wikidata.org/wiki/Q7345" class="extiw" title="d:Q7345">editar datos en Wikidata</a></span>]</small></td>
# </tr>
# </table>
# <p><b>Daniel «Dan» Brown</b> (<a href="/wiki/Exeter_(Nuevo_Hampshire)" title="Exeter (Nuevo Hampshire)">Exeter</a>, <a href="/wiki/Nuevo_Hampshire" title="Nuevo Hampshire">Nuevo Hampshire</a>, <a href="/wiki/Estados_Unidos" title="Estados Unidos">Estados Unidos</a>, <a href="/wiki/22_de_junio" title="22 de junio">22 de junio</a> de <a href="/wiki/1964" title="1964">1964</a>) es un <a href="/wiki/Escritor" title="Escritor">escritor</a> <a href="/wiki/Estados_Unidos" title="Estados Unidos">estadounidense</a> conocido por la novela <i><a href="/wiki/El_c%C3%B3digo_Da_Vinci_(novela)" class="mw-redirect" title="El código Da Vinci (novela)">El código Da Vinci</a></i> (<a href="/wiki/2003" title="2003">2003</a>) y otros títulos protagonizados por el personaje <a href="/wiki/Robert_Langdon" title="Robert Langdon">Robert Langdon</a>.</p>
# <p></p>
# <div id="toc" class="toc">
# <div class="toctitle" lang="es" dir="ltr" xml:lang="es">
# <h2>Índice</h2>
# </div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Biografía"><span class="tocnumber">1</span> <span class="toctext">Biografía</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#
# <p>Regresaron a <a href="/wiki/Nuevo_Hampshire" title="Nuevo Hampshire">Nuevo Hampshire</a>, donde continuó con su carrera musical y dando clases de inglés en la <a href="/w/index.php?title=Philix_Exeter_Academy&amp;action=edit&amp;redlink=1" class="new" title="Philix Exeter Academy (aún no redactado)">Philix Exeter Academy</a> y de español en la <a href="/w/index.php?title=Lincoln_Akerman_School&amp;action=edit&amp;redlink=1" class="new" title="Lincoln Akerman School (aún no redactado)">Lincoln Akerman School</a>. En <a href="/wiki/1993" title="1993">1993</a>, además, grabó <i>Dan Brown</i> y en <a href="/wiki/1994" title="1994">1994</a> <i>Angels and demons</i>, título que conservaría para <a href="/wiki/%C3%81ngeles_y_demonios_(novela)" title="Ángeles y demonios (novela)">su segunda novela</a>.</p>
# <p>Pero, todo cambió en el verano de <a href="/wiki/1993" title="1993">1993</a>. Mientras estaba en una playa de <a href="/wiki/Tahit%C3%AD" title="Tahití">Tahití</a>, encontró olvidada en una tumbona la novela <i><a href="/w/index.php?title=La_conspiraci%C3%B3n_del_juicio_final&amp;action=edit&amp;redlink=1" class="new" title="La conspiración del juicio final (aún no redactado)">La conspiración del juicio final</a></i> (<a href="/wiki/1991" title="1991">1991</a>), de <a href="/wiki/Sidney_Sheldon" title="Sidney Sheldon">Sidney Sheldon</a>. Al regresar a Exeter, comenzó a trabajar en <i>Digital Fortress</i> (<i><a href="/wiki/La_fortaleza_digital" title="La fortaleza digital">La fortaleza digital</a></i>), su primera novela, en la que involucraba en la intriga a la <a href="/wiki/Agencia_de_Seguridad_Nacional" title="Agencia de Seguridad Nacional">Agencia de Seguridad Nacional</a> (<a href="/wiki/NSA" class="mw-redirect" title="NSA">NSA</a>). Este <a href="/wiki/Techno-thriller" class="mw-redirect" title="Techno-thriller">techno-thriller</a>, aparecido en <a href="/wiki/1998" title="1998">1998</a>, criticado por su superficialidad y deslices en el tratamiento tecnológico, tuvo un relativo éxito comercial.</p>
# <p>En el año <a href="/wiki/2000" title="2000">2000</a> publica <i><a href="/wiki/%C3%81ngeles_y_demonios_(novela)" title="Ángeles y demonios (novela)">Ángeles y demonios</a></i>, donde aparece por primera vez el personaje <a href="/wiki/Robert_Langdon" title="Robert Langdon">Robert Langdon</a>, profesor de simbología religiosa en la <a href="/wiki/Universidad_de_Harvard" title="Universidad de Harvard">Universidad de Harvard</a> que, investigando un misterioso símbolo, se encuentra con la secta de los <a href="/wiki/Illuminati" class="mw-redirect" title="Illuminati">Illuminati</a>, hermandad que lleva siglos enfrentada a la <a href="/wiki/Iglesia_cat%C3%B3lica" title="Iglesia católica">Iglesia católica</a>.</p>
span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Dan_Brown&amp;action=edit&amp;section=5" title="Editar sección: Obras de humor">editar</a><span class="mw-editsection-bracket">]</span></span></h3>
# <ul>
# <li><i>187 Men to Avoid: A Survival Guide for the Romantically Frustrated Woman</i> (1995, coescrito bajo el pseudónimo de Danielle Brown)</li>
# <li><i>The Bald Book</i> (1998, co-coescrito junto a su esposa)</li>
# </ul>
# <h2><span class="mw-headline" id="Argumento_de_sus_obras">Argumento de sus obras</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Dan_Brown&amp;action=edit&amp;section=6" title="Editar sección: Argumento de sus obras">editar</a><span class="mw-editsection-bracket">]</span></span></h2>
# <h3><span class="mw-headline" id="La_fortaleza_digital"><i>La fortaleza digital</i></span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Dan_Brown&amp;action=edit&amp;section=7" title="Editar sección: La fortaleza digital">editar</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="noprint AP rellink"><span style="font-size:88%">Artículo principal:</span> <i><a href="/wiki/La_fortaleza_digital" title="La fortaleza digital">La fortaleza digital</a></i></div>
# <p>Su primera novela tiene como protagonista a Susan Fletcher, una de las mejores criptógrafas de la <a href="/wiki/Agencia_de_Seguridad_Nacional" title="Agencia de Seguridad Nacional">NSA</a>, que verá peligrar su vida con la llegada de un extraño código que, a primera vista, ni ella misma sabe descifrar. Paralelamente y sin que Susan lo sepa, su prometido, el traductor David Becker, es enviado por la NSA a Sevilla en busca de la clave para resolver el misterio, mientras es seguido de cerca por un implacable asesino a sueldo.</p>
# <h3><span id=".C3.81ngeles_y_demonios"></span><span class="mw-headline" id="Ángeles_y_demonios"><i>Ángeles y demonios</i></span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Dan_Brown&amp;action=edit&amp;section=8" title="Editar sección: Ángeles y demonios">editar</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="noprint AP rellink"><span style="font-size:88%">Artículo principal:</span> <i><a href="/wiki/%C3%81ngeles_y_demonios_(novela)" title="Ángeles y demonios (novela)">Ángeles y demonios</a></i></div>
# <p>Su segunda novela es, a su vez, la primera de una serie de aventuras protagonizada por el profesor de simbología y arte religioso de <a href="/wiki/Harvard" class="mw-redirect" title="Harvard">Harvard</a>, <a href="/wiki/Robert_Langdon" title="Robert Langdon">Robert Langdon</a>. En este caso, el profesor Langdon y la científica del <a href="/wiki/Organizaci%C3%B3n_Europea_para_la_Investigaci%C3%B3n_Nuclear" title="Organización Europea para la Investigación Nuclear">CERN</a> Vittoria Vetra se verán envueltos en una carrera contra el tiempo por salvar al <a href="/wiki/Ciudad_del_Vaticano" title="Ciudad del Vaticano">Vaticano</a> de un atentado terrorista organizado por una hermandad secreta que se creía desaparecida, los <a href="/wiki/Illuminati" class="mw-redirect" title="Illuminati">Illuminati</a>, que involucra una bomba de <a href="/wiki/Antimateria" title="Antimateria">antimateria</a> y el secuestro de cuatro cardenales <i><a href="/wiki/Papable" title="Papable">preferiti</a></i> en pleno <a href="/wiki/C%C3%B3nclave" title="Cónclave">cónclave</a> papal.</p>
# <h3><span id="La_conspiraci.C3.B3n"></span><span class="mw-headline" id="La_conspiración"><i>La conspiración</i></span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Dan_Brown&amp;action=edit&amp;section=9" title="Editar sección: La conspiración">editar</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="noprint AP rellink"><span style="font-size:88%">Artículo principal:</span> <i><a href="/wiki/La_conspiraci%C3%B3n" title="La conspiración">La conspiración</a></i></div>
# <p>Su tercera novela gira en torno a una red de conspiraciones que se desencadena tras el descubrimiento, por parte de la <a href="/wiki/NASA" title="NASA">NASA</a>, de un meteorito enterrado en la <a href="/wiki/Plataforma_de_hielo_Milne" title="Plataforma de hielo Milne">plataforma de hielo Milne</a> (<a href="/wiki/Canad%C3%A1" title="Canadá">Canadá</a>, cerca del <a href="/wiki/Polo_Norte" class="mw-redirect" title="Polo Norte">Polo Norte</a>) que parece presentar pruebas irrefutables de la existencia de <a href="/wiki/Vida_extraterrestre" title="Vida extraterrestre">vida extraterrestre</a>. Su protagonista es la analista de inteligencia Rachel Sexton.</p>
# <h3><span id="El_c.C3.B3digo_Da_Vinci"></span><span class="mw-headline" id="El_código_Da_Vinci"><i>El código Da Vinci</i></span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Dan_Brown&amp;action=edit&amp;section=10" title="Editar sección: El código Da Vinci">editar</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="noprint AP rellink"><span style="font-size:88%">Artículo principal:</span> <i><a href="/wiki/El_c%C3%B3digo_Da_Vinci_(novela)" class="mw-redirect" title="El código Da Vinci (novela)">El código Da Vinci</a></i></div>
# <p>En su cuarta novela, la más popular, y, posiblemente, <a href="/wiki/Cr%C3%ADticas_a_%C2%ABEl_c%C3%B3digo_Da_Vinci%C2%BB" title="Críticas a «El código Da Vinci»">la más polémica</a> de todas, Brown recupera al personaje de <a href="/wiki/Robert_Langdon" title="Robert Langdon">Robert Langdon</a>, que ahora debe solucionar un misterio con la criptóloga Sophie Neveu, relacionado con una sociedad secreta conocida como el <a href="/wiki/Priorato_de_Sion" title="Priorato de Sion">Priorato de Sion</a>, de la que <a href="/wiki/Leonardo_da_Vinci" title="Leonardo da Vinci">Leonardo da Vinci</a> habría sido Gran Maestre, y la posible ubicación del <a href="/wiki/Santo_Grial" class="mw-redirect" title="Santo Grial">Santo Grial</a>. Langdon y Sophie parten en busca del Grial por distintas locaciones de <a href="/wiki/Par%C3%ADs" title="París">París</a> y <a href="/wiki/Londres" title="Londres">Londres</a>, mientras un monje albino asesino trabaja presuntamente a las órdenes del <a href="/wiki/Opus_Dei" title="Opus Dei">Opus Dei</a> para mantener oculto el secreto.</p>
# <h3><span id="El_s.C3.ADmbolo_perdido"></span><span class="mw-headline" id="El_símbolo_perdido"><i>El símbolo perdido</i></span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Dan_Brown&amp;action=edit&amp;section=11" title="Editar sección: El símbolo perdido">editar</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="noprint AP rellink"><span style="font-size:88%">Artículo principal:</span> <i><a href="/wiki/El_s%C3%ADmbolo_perdido" title="El símbolo perdido">El símbolo perdido</a></i></div>
# <p>En su quinta novela, trata el tema de la <a href="/wiki/Francmasoner%C3%ADa" title="Francmasonería">masonería</a><sup id="cite_ref-1" class="reference separada"><a href="#cite_note-1"><span class="corchete-llamada">[</span>1<span class="corchete-llamada">]</span></a></sup>​ con el personaje de <a href="/wiki/Robert_Langdon" title="Robert Langdon">Robert Langdon</a> como protagonista. Esta vez, deberá salvar la vida de un viejo amigo, Peter Solomon, y evitar que un secreto muy bien guardado caiga en malas manos, con la ayuda de la científica del <a href="/wiki/Instituto_de_Ciencias_No%C3%A9ticas" title="Instituto de Ciencias Noéticas">Instituto de Ciencias Noéticas</a> Katherine Solomon, hermana de Peter.</p>
# <p>Fue publicada el <a href="/wiki/15_de_septiembre" title="15 de septiembre">15 de septiembre</a> de <a href="/wiki/2009" title="2009">2009</a> en <a href="/wiki/Estados_Unidos" title="Estados Unidos">Estados Unidos</a> y el <a href="/wiki/29_de_octubre" title="29 de octubre">29 de octubre</a> de <a href="/wiki/2009" title="2009">2009</a> en <a href="/wiki/Espa%C3%B1a" title="España">España</a>.<sup id="cite_ref-2" class="reference separada"><a href="#cite_note-2"><span class="corchete-llamada">[</span>2<span class="corchete-llamada">]</span></a></sup>​</p>
# <h3><span class="mw-headline" id="Inferno"><i>Inferno</i></span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Dan_Brown&amp;action=edit&amp;section=12" title="Editar sección: Inferno">editar</a><span class="mw-editsection-bracket">]</span></span></h3>
# <div class="noprint AP rellink"><span style="font-size:88%">Artículo principal:</span> <i><a href="/wiki/Inferno_(novela_de_Dan_Brown)" title="Inferno (novela de Dan Brown)">Inferno</a></i></div>
# <p>Es su sexta novela y la cuarta protagonizada por el experto en simbología <a href="/wiki/Robert_Langdon" title="Robert Langdon">Robert Langdon</a
wikipedia.org/wiki/Dan_Brown" title="Dan Brown (Samogitian)" lang="bat-smg" hreflang="bat-smg" class="interlanguage-link-target">Žemaitėška</a></li><li class="interlanguage-link interwiki-be"><a href="https://be.wikipedia.org/wiki/%D0%94%D1%8D%D0%BD_%D0%91%D1%80%D0%B0%D1%9E%D0%BD" title="Дэн Браўн (bielorruso)" lang="be" hreflang="be" class="interlanguage-link-target">Беларуская</a></li><li class="interlanguage-link interwiki-bg"><a href="https://bg.wikipedia.org/wiki/%D0%94%D0%B0%D0%BD_%D0%91%D1%80%D0%B0%D1%83%D0%BD" title="Дан Браун (búlgaro)" lang="bg" hreflang="bg" class="interlanguage-link-target">Български</a></li><li class="interlanguage-link interwiki-bn"><a href="https://bn.wikipedia.org/wiki/%E0%A6%A1%E0%A7%8D%E0%A6%AF%E0%A6%BE%E0%A6%A8_%E0%A6%AC%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%89%E0%A6%A8" title="ড্যান ব্রাউন (bengalí)" lang="bn" hreflang="bn" class="interlanguage-link-target">বাংলা</a></li><li class="interlanguage-link interwiki-bs"><a href="https://bs.wikipedia.org/wiki/Dan_Brown" title="Dan Brown (bosnio)" lang="bs" hreflang="bs" class="interlanguage-link-target">Bosanski</a></li><li class="interlanguage-link interwiki-ca"><a href="https://ca.wikipedia.org/wiki/Dan_Brown" title="Dan Brown (catalán)" lang="ca" hreflang="ca" class="interlanguage-link-target">Català</a></li><li class="interlanguage-link interwiki-ckb"><a href="https://ckb.wikipedia.org/wiki/%D8%AF%D8%A7%D9%86_%D8%A8%D8%B1%D8%A7%D9%88%D9%86" title="دان براون (kurdo sorani)" lang="ckb" hreflang="ckb" class="interlanguage-link-target">کوردی</a></li><li class="interlanguage-link interwiki-cs"><a href="https://cs.wikipedia.org/wiki/Dan_Brown" title="Dan Brown (checo)" lang="cs" hreflang="cs" class="interlanguage-link-target">Čeština</a></li><li class="interlanguage-link interwiki-cy"><a href="https://cy.wikipedia.org/wiki/Dan_Brown" title="Dan Brown (galés)" lang="cy" hreflang="cy" class="interlanguage-link-target">Cymraeg</a></li><li class="interlanguage-link interwiki-da"><a href="https://da.wikipedia.org/wiki/Dan_Brown" title="Dan Brown (danés)" lang="da" hreflang="da" class="interlanguage-link-target">Dansk</a ...
# 				<div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q7345#sitelinks-wikipedia" title="Editar enlaces interlingüísticos" class="wbc-editpage">Editar enlaces</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 				<div id="footer" role="contentinfo">
# 						<ul id="footer-info">
# 								<li id="footer-info-lastmod"> Se editó esta página por última vez el 23 abr 2018 a las 23:07.</li>
# 								<li id="footer-info-copyright">El texto está disponible bajo la <a rel="license" href="//es.wikipedia.org/wiki/Wikipedia:Texto_de_la_Licencia_Creative_Commons_Atribuci%C3%B3n-CompartirIgual_3.0_Unported">Licencia Creative Commons Atribución Compartir Igual 3.0</a><a rel="license" href="http://creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# pueden aplicarse cláusulas adicionales. Al usar este sitio, usted acepta nuestros <a href="//wikimediafoundation.org/wiki/Terms_of_Use">términos de uso</a> y nuestra <a href="//wikimediafoundation.org/wiki/Privacy_policy">política de privacidad</a>. <br/>Wikipedia&reg; es una marca registrada de la <a href="//www.wikimediafoundation.org/">Fundación Wikimedia, Inc.</a>, una organización sin ánimo de lucro.</li>
# 							</ul>
# 						<ul id="footer-places">
# 								<li id="footer-places-privacy"><a href="https://meta.wikimedia.org/wiki/Privacy_policy/es" class="extiw" title="m:Privacy policy/es">Normativa de privacidad</a></li>
# 								<li id="footer-places-about"><a href="/wiki/Wikipedia:Acerca_de" title="Wikipedia:Acerca de">Acerca de Wikipedia</a></li>
# 								<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:Limitaci%C3%B3n_general_de_responsabilidad" title="Wikipedia:Limitación general de responsabilidad">Limitación de responsabilidad</a></li>
# 								<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Desarrolladores</a></li>
# 								<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement/es">Declaración de cookies</a></li>
# 								<li id="footer-places-mobileview"><a href="//es.m.wikipedia.org/w/index.php?title=Dan_Brown&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Versión para móviles</a></li>
# 							</ul>
# 										<ul id="footer-icons" class="noprint">
# 										<li id="footer-copyrightico">
# 						<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>					</li>
# 										<li id="footer-poweredbyico">
# 						<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>					</li>
# 									</ul>
# 						<div style="clear: both;"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.280","walltime":"0.378","ppvisitednodes":{"value":2667,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":32340,"limit":2097152},"templateargumentsize":{"value":2595,"limit":2097152},"expansiondepth":{"value":21,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":1375,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  301.114      1 -total"," 57.57%  173.359      1 Plantilla:Ficha_de_escritor"," 16.25%   48.917      1 Plantilla:Referencias_adicionales"," 11.63%   35.012      1 Plantilla:NF"," 11.26%   33.911      1 Plantilla:Metaplantilla_de_avisos"," 10.15%   30.576      2 Plantilla:Problemas_artículo/validar","  8.64%   26.010      1 Plantilla:Commonscat","  8.12%   24.437      1 Plantilla:Control_de_autoridades","  7.76%   23.364      1 Plantilla:Gentilicio","  6.84%   20.591      1 Plantilla:Propiedad"]},"scribunto":{"limitreport-timeusage":{"value":"0.138","limit":"10.000"},"limitreport-memusage":{"value":3645590,"limit":52428800}},"cachereport":{"origin":"mw1308","timestamp":"20180501120644","ttl":3600,"transientcontent":true}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":103,"wgHostname":"mw1261"});});</script>
# 	</body>
# </html>

# %%
# Crear un objeto BeautifulSoup desde el HTML
soup = BeautifulSoup(html_doc, "lxml")

# %%
# Obtener el titulo del web page de Dan Brown

dan_title = soup.title

print(dan_title)
# Out:
# <title>Dan Brown - Wikipedia, la enciclopedia libre</title>

# %%
# Extraeremos el texto de la pagina de wikipedia de Dan Brown.

texto_dan = soup.get_text()

# %%
print(texto_dan)
# Out:
# Dan Brown - Wikipedia, la enciclopedia libre
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
# (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Dan_Brown","wgTitle":"Dan Brown","wgCurRevisionId":107240258,"wgRevisionId":107240258,"wgArticleId":41826,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Artículos que necesitan referencias adicionales","Wikipedia:Referenciar (aún sin clasificar)","Personas vivas","Wikipedia:Control de autoridades con 15 elementos","Wikipedia:Artículos con identificadores VIAF","Wikipedia:Artículos con identificadores ISNI","Wikipedia:Artículos con identificadores BNE","Wikipedia:Artículos con identificadores BNF","Wikipedia:Artículos con identificadores CANTIC","Wikipedia:Artículos con identificadores GND","Wikipedia:Artículos con identificadores LCCN","Wikipedia:Artículos con identificadores SNAC","Wikipedia:Artículos con identificadores SELIBR","Wikipedia:Artículos con identificadores BIBSYS","Wikipedia:Artículos con identificadores SBN","Wikipedia:Artículos con identificadores Open Library","Wikipedia:Referenciar literatura","Hombres","Nacidos en 1964","Escritores de Estados Unidos","Agnósticos","Escritores en inglés","Escritores de suspenso"],"wgBreakFrames":false,"wgPageContentLanguage":"es","wgPageContentModel":"wikitext","wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgMonthNamesShort":["","ene","feb","mar","abr","may","jun","jul","ago","sep","oct","nov","dic"],"wgRelevantPageName":"Dan_Brown","wgRelevantArticleId":41826,"wgRequestId":"WuhlCwpAADgAAAMs6LcAAADM","wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"es","wgMFExpandAllSectionsUserOption":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"español","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgWikibaseItemId":"Q7345","wgScoreNoteLanguages":{"arabic":"العربية","catalan":"català","deutsch":"Deutsch","english":"English","espanol":"español","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"português","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":false,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true});mw.loader.state({"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ex ...
# });mw.loader.implement("user.tokens@1dqfd7l",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });mw.loader.load(["ext.cite.a11y","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.toc","mediawiki.searchSuggest","ext.gadget.a-commons-directo","ext.gadget.refToolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.compactlinks","ext.uls.interface","ext.3d","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Dan Brown
# De Wikipedia, la enciclopedia libre
#
# 					Saltar a:					navegación, 					búsqueda
#
#
#
#
#
#
# Este artículo tiene referencias, pero necesita más para complementar su verificabilidad.
# Puedes colaborar agregando referencias a fuentes fiables como se indica aquí. El material sin fuentes fiables podría ser cuestionado y eliminado.
# Este aviso fue puesto el 23 de abril de 2018.
#
#
#
#
# Dan Brown
#
#
#
#
#
# Información personal
#
#
# Nombre de nacimiento
# Daniel Brown
#
#
# Nacimiento
# 22 de junio de 1964 (53 años)
# Exeter, Nuevo Hampshire,
#  Estados Unidos
#
#
# Nacionalidad
# Estadounidense
#
#
# Lengua materna
# Inglés
#
#
# Religión
# Agnosticismo
#
#
# Familia
#
#
# Cónyuge
# Blythe Brown
#
#
# Educación
#
#
# Alma máter
#
#
# Amherst College
# Phillips Exeter Academy
#
#
#
#
# Información profesional
#
#
# Ocupación
# Escritor
#
#
# Años activo
# desde 1998
#
#
# Género
# Novela
#
#
# Obras notables
#
#
# La fortaleza digital
# La conspiración
# Ángeles y demonios
# El código Da Vinci
# El símbolo perdido
# Inferno
# Origen
#
#
#
#
# Distinciones
#
#
# Crimezone Thriller Awards (2004)
# Humo's Gouden Bladwijzer (2005)
#
#
#
#
# Firma
#
#
#
# Web
#
#
# Sitio web
#
# www.danbrown.com
#
#
#
# Facebook
# DanBrown
#
#
# Twitter
# AuthorDanBrown
#
#
# [editar datos en Wikidata]
#
#
# Daniel «Dan» Brown (Exeter, Nuevo Hampshire, Estados Unidos, 22 de junio de 1964) es un escritor estadounidense conocido por la novela El código Da Vinci (2003) y otros títulos protagonizados por el personaje Robert Langdon.
#
#
#
# Índice
#
#
# 1 Biografía
# 2 Obras
#
# 2.1 Novelas independientes
# 2.2 Serie Robert Langdon
# 2.3 Obras de humor
#
#
# 3 Argumento de sus obras
#
# 3.1 La fortaleza digital
# 3.2 Ángeles y demonios
# 3.3 La conspiración
# 3.4 El código Da Vinci
# 3.5 El símbolo perdido
# 3.6 Inferno
# 3.7 Origen
#
#
# 4 Adaptaciones cinematográficas
# 5 Referencias
# 6 Enlaces externos
#
#
#
# Biografía[editar]
# Hijo de un matemático y una compositora de música sacra. Estudió en la Phillips Exeter Academy y en el Amherst College. Como estudiante residió en Gijón (España) en el año de 1980, este traslado a España fue su primer viaje al extranjero estudiando en un instituto de dicha ciudad. Brown afirma que en 1985, un año antes de graduarse, estudió Historia del Arte en la Universidad de Sevilla, pero esta universidad declaró que no existen registros de que él hubiese sido estudiante en sus instalaciones, y que en caso de haberlo sido es probable que lo haya hecho como un estudiante itinerante en un simple curso de verano. Diplomado por el Amherst College, se dedicó a la música: produjo una grabación con canciones infantiles y fundó la empresa Dalliance, con la que grabó Perspective.
# En 1991 se mudó a Hollywood, California, para continuar con su carrera de pianista y cantautor, mientras se ganaba la vida como profesor de inglés y español en un colegio de Beverly Hills. En la Academia Nacional de Compositores conoció a Blythe Newlon, una mujer quince años mayor, con quien contrajo matrimonio en 1997 después de varios años de convivencia.
# Regresaron a Nuevo Hampshire, donde continuó con su carrera musical y dando clases de inglés en la Philix Exeter Academy y de español en la Lincoln Akerman School. En 1993, además, grabó Dan Brown y en 1994 Angels and demons, título que conservaría para su segunda novela.
# Pero, todo cambió en el verano de 1993. Mientras estaba en una playa de Tahití, encontró olvidada en una tumbona la novela La conspiración del juicio final (1991), de Sidney Sheldon. Al regresar a Exeter, comenzó a trabajar en Digital Fortress (La fortaleza digital), su primera novela, en la que involucraba en la intriga a la Agencia de Seguridad Nacional (NSA). Este techno-thriller, aparecido en 1998, criticado por su superficialidad y deslices en el tratamiento tecnológico, tuvo un relativo éxito comercial.
# En el año 2000 publica Ángeles y demonios, donde aparece por primera vez el personaje Robert Langdon, profesor de simbología religiosa en la Universidad de Harvard que, investigando un misterioso símbolo, se encuentra con la secta de los Illuminati, hermandad que lleva siglos enfrentada a la Iglesia católica.
# Al año siguiente aparece Deception Point (2001, traducida al español como La conspiración), libro que motoriza su trama con el descubrimiento de un extraño objeto en el Ártico por parte de un satélite (SOT) de la NASA.
# Langdon, el personaje clave de Ángeles y demonios, es también el protagonista de la obra que lo convirtió en fenómeno mundial de superventas, El código Da Vinci, un libro centrado en la búsqueda del significado real del Santo Grial.
# Obras[editar]
# En negrita figuran las obras publicadas en español.
# Novelas independientes[editar]
#
# La fortaleza digital (Digital Fortress, 1998, ed. Umbriel)
# La conspiración (Deception Point, 2001, ed. Umbriel)
#
# Serie Robert Langdon[editar]
#
# Ángeles y demonios (Angels & Demons, 2000, ed. Umbriel). Adaptada al cine en 2009.
# El código Da Vinci (The Da Vinci Code, 2003, ed. Umbriel). Adaptada al cine en 2006.
# El símbolo perdido (The Lost Symbol, 2009, ed. Planeta)
# Inferno (Inferno, 2013, ed. Planeta). Adaptada al cine en 2016.
# Origen (Origin, 2017, ed. Planeta).
#
# Obras de humor[editar]
#
# 187 Men to Avoid: A Survival Guide for the Romantically Frustrated Woman (1995, coescrito bajo el pseudónimo de Danielle Brown)
# The Bald Book (1998, co-coescrito junto a su esposa)
#
# Argumento de sus obras[editar]
# La fortaleza digital[editar]
# Artículo principal: La fortaleza digital
# Su primera novela tiene como protagonista a Susan Fletcher, una de las mejores criptógrafas de la NSA, que verá peligrar su vida con la llegada de un extraño código que, a primera vista, ni ella misma sabe descifrar. Paralelamente y sin que Susan lo sepa, su prometido, el traductor David Becker, es enviado por la NSA a Sevilla en busca de la clave para resolver el misterio, mientras es seguido de cerca por un implacable asesino a sueldo.
# Ángeles y demonios[editar]
# Artículo principal: Ángeles y demonios
# Su segunda novela es, a su vez, la primera de una serie de aventuras protagonizada por el profesor de simbología y arte religioso de Harvard, Robert Langdon. En este caso, el profesor Langdon y la científica del CERN Vittoria Vetra se verán envueltos en una carrera contra el tiempo por salvar al Vaticano de un atentado terrorista organizado por una hermandad secreta que se creía desaparecida, los Illuminati, que involucra una bomba de antimateria y el secuestro de cuatro cardenales preferiti en pleno cónclave papal.
# Inferno (Inferno, 2016, 4ª novela de la serie), dirigida por Ron Howard, protagonizada por Tom Hanks y Felicity Jones, y con las interpretaciones secundarias de Irrfan Khan, Omar Sy y Ben Foster.
#
# La versión cinematográfica de El símbolo perdido (3ª novela de la serie) ha sufrido numerosos retrasos en la producción. El 20 de octubre de 2011 se anunció que el director Ron Howard había rechazado el proyecto, pasando a manos de Mark Romanek; sin embargo, en julio de 2013 Sony Pictures confirmó que la próxima película de la saga sería Inferno, dirigida por Howard, por lo que la adaptación de El símbolo perdido quedó pospuesta indefinidamente.
# Referencias[editar]
#
#
# ↑ Ver artículo Dan Brown: "En España descubrí una opresión religiosa nunca vista", 29 de octubre de 2009 en el periódico español Público
# ↑ Terra - Dan Brown regresará en septiembre a las librerías con "El símbolo perdido"
#
#
# Enlaces externos[editar]
#
#  Wikimedia Commons alberga una categoría multimedia sobre Dan Brown.
#  Wikiquote alberga frases célebres de o sobre Dan Brown.
# DanBrown.com (sitio oficial)
# Dan Brown (sitio oficial en Reino Unido)
# Libro Origen
#
#
#
#
#
# Control de autoridades
#
#
#
# : Q7345
# WorldCat
# VIAF: 102403515
# ISNI: 0000 0001 0929 7080
# BNE: XX1660007
# BNF: cb14529449m (data)
# CANTIC: a11978776
# GND: 124429548
# LCCN: n95086067
# NDL: 00934700
# NKC: xx0008745
# SNAC: w6s21ttq
# SUDOC: 07418105X
# SELIBR: 258460
# BIBSYS: 4045029
# ICCU: IT\ICCU\RAVV\366833
# Open Library: OL39307A
#
#
#
#
#
#
#
#
#
#
#
# 						Obtenido de «https://es.wikipedia.org/w/index.php?title=Dan_Brown&oldid=107240258»
# Categorías: HombresNacidos en 1964Escritores de Estados UnidosAgnósticosEscritores en inglésEscritores de suspensoCategorías ocultas: Wikipedia:Artículos que necesitan referencias adicionalesWikipedia:Referenciar (aún sin clasificar)Personas vivasWikipedia:Control de autoridades con 15 elementosWikipedia:Artículos con identificadores VIAFWikipedia:Artículos con identificadores ISNIWikipedia:Artículos con identificadores BNEWikipedia:Artículos con identificadores BNFWikipedia:Artículos con identificadores CANTICWikipedia:Artículos con identificadores GNDWikipedia:Artículos con identificadores LCCNWikipedia:Artículos con identificadores SNACWikipedia:Artículos con identificadores SELIBRWikipedia:Artículos con identificadores BIBSYSWikipedia:Artículos con identificadores SBNWikipedia:Artículos con identificadores Open LibraryWikipedia:Referenciar literatura
#
#
#
# Menú de navegación
#
#
# Herramientas personales
#
# No has accedidoDiscusiónContribucionesCrear una cuentaAcceder
#
#
#
# Espacios de nombres
#
# ArtículoDiscusión
#
#
#
#
# Variantes
#
#
#
#
#
#
#
#
#
# Vistas
#
# LeerEditarVer historial
#
#
#
# Más
#
#
#
#
#
#
#
# Buscar
#
#
#
#
#
#
#
#
#
#
#
# Navegación
#
#
# PortadaPortal de la comunidadActualidadCambios recientesPáginas nuevasPágina aleatoriaAyudaDonacionesNotificar un error
#
#
#
# Imprimir/exportar
#
#
# Crear un libroDescargar como PDFVersión para imprimir
#
#
#
# En otros proyectos
#
#
# Wikimedia CommonsWikiquote
#
#
#
# Herramientas
#
#
# Lo que enlaza aquíCambios en enlazadasSubir archivoPáginas especialesEnlace permanenteInformación de la páginaElemento de WikidataCitar esta página
#
#
#
# En otros idiomas
#
#
# AfrikaansAragonésالعربيةمصرىঅসমীয়াAsturianuAzərbaycancaتۆرکجهŽemaitėškaБеларускаяБългарскиবাংলাBosanskiCatalàکوردیČeštinaCymraegDanskDeutschΕλληνικάEnglishEsperantoEestiEuskaraفارسیSuomiFrançaisFryskGaeilgeGalegoעבריתHrvatskiMagyarՀայերենBahasa IndonesiaItaliano日本語ქართულიҚазақшаಕನ್ನಡ한국어LatinaLëtzebuergeschLietuviųLatviešuМакедонскиമലയാളംनेपालीNederlandsNorsk nynorskNorskOccitanਪੰਜਾਬੀKapampanganPolskiPortuguêsRomânăРусскийSicilianuScotsSimple EnglishSlovenčinaSlovenščinaShqipСрпски / srpskiSvenskaதமிழ்ไทยTagalogTürkçeУкраїнськаاردوOʻzbekcha/ўзбекчаTiếng ViệtZeêuws中文
# Editar enlaces
#
#
#
#
#
#  Se editó esta página por última vez el 23 abr 2018 a las 23:07.
# El texto está disponible bajo la Licencia Creative Commons Atribución Compartir Igual 3.0;
# pueden aplicarse cláusulas adicionales. Al usar este sitio, usted acepta nuestros términos de uso y nuestra política de privacidad. Wikipedia® es una marca registrada de la Fundación Wikimedia, Inc., una organización sin ánimo de lucro.
#
#
# Normativa de privacidad
# Acerca de Wikipedia
# Limitación de responsabilidad
# Desarrolladores
# Declaración de cookies
# Versión para móviles
#
#
#
#
#
#
#
#
#
# (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.280","walltime":"0.378","ppvisitednodes":{"value":2667,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":32340,"limit":2097152},"templateargumentsize":{"value":2595,"limit":2097152},"expansiondepth":{"value":21,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":1375,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  301.114      1 -total"," 57.57%  173.359      1 Plantilla:Ficha_de_escritor"," 16.25%   48.917      1 Plantilla:Referencias_adicionales"," 11.63%   35.012      1 Plantilla:NF"," 11.26%   33.911      1 Plantilla:Metaplantilla_de_avisos"," 10.15%   30.576      2 Plantilla:Problemas_artículo/validar","  8.64%   26.010      1 Plantilla:Commonscat","  8.12%   24.437      1 Plantilla:Control_de_autoridades","  7.76%   23.364      1 Plantilla:Gentilicio","  6.84%   20.591      1 Plantilla:Propiedad"]},"scribunto":{"limitreport-timeusage":{"value":"0.138","limit":"10.000"},"limitreport-memusage":{"value":3645590,"limit":52428800}},"cachereport":{"origin":"mw1308","timestamp":"20180501120644","ttl":3600,"transientcontent":true}}});});(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":103,"wgHostname":"mw1261"});});

# %%
# con el método find_all() se encontrarán todos los hypervinculos, todos estos emíezan con <a> en html,
# por ello buscamos 'a

a_tags = soup.find_all('a')

# %%
# Para cada objeto encontrado extraemos el link y lo imprimimos

for link in a_tags:
    print(link.get('href'))
# Out:
# None
# #mw-head
# #p-search
# /wiki/Wikipedia:Referencias
# /wiki/Wikipedia:Verificabilidad
# /wiki/Wikipedia:Fuentes_fiables
# /wiki/Ayuda:C%C3%B3mo_referenciar
# /wiki/Wikipedia:Wikipedia_no_es_una_fuente_primaria
# /wiki/Archivo:Dan_Brown_bookjacket_cropped.jpg
# /wiki/22_de_junio
# /wiki/1964
# /wiki/Exeter_(Nuevo_Hampshire)
# /wiki/Nuevo_Hampshire
# /wiki/Estados_Unidos
# /wiki/Estados_Unidos
# https://www.wikidata.org/wiki/Q7345?uselang=es#P27
# /wiki/Idioma_ingl%C3%A9s
# https://www.wikidata.org/wiki/Q7345?uselang=es#P103
# /wiki/Agnosticismo
# https://www.wikidata.org/wiki/Q7345?uselang=es#P140
# /wiki/Amherst_College
# /wiki/Phillips_Exeter_Academy
# https://www.wikidata.org/wiki/Q7345?uselang=es#P69
# /wiki/Novela
# /wiki/La_fortaleza_digital
# /wiki/La_conspiraci%C3%B3n
# /wiki/%C3%81ngeles_y_demonios_(novela)
# /wiki/El_c%C3%B3digo_Da_Vinci
# /wiki/El_s%C3%ADmbolo_perdido
# /wiki/Inferno_(novela_de_Dan_Brown)
# /wiki/Origen_(novela_de_Dan_Brown)
# https://www.wikidata.org/wiki/Q7345?uselang=es#P800
# https://www.wikidata.org/wiki/Q7345?uselang=es#P166
# /wiki/Archivo:Dan_Brown%27s_signature.svg
# http://www.danbrown.com/
# https://www.wikidata.org/wiki/Q7345?uselang=es#P856
# https://www.facebook.com/DanBrown
# https://www.wikidata.org/wiki/Q7345?uselang=es#P2013
# https://twitter.com/AuthorDanBrown
# https://www.wikidata.org/wiki/Q7345?uselang=es#P2002
# https://www.wikidata.org/wiki/Q7345
# /wiki/Exeter_(Nuevo_Hampshire)
# /wiki/Nuevo_Hampshire
# /wiki/Estados_Unidos
# /wiki/22_de_junio
# /wiki/1964
# /wiki/Escritor
# /wiki/Estados_Unidos
# /wiki/El_c%C3%B3digo_Da_Vinci_(novela)
# /wiki/2003
# /wiki/Robert_Langdon
# #Biografía
# #Obras
# #Novelas_independientes
# #Serie_Robert_Langdon
# #Obras_de_humor
# #Argumento_de_sus_obras
# #La_fortaleza_digital
# #Ángeles_y_demonios
# #La_conspiración
# #El_código_Da_Vinci
# #El_símbolo_perdido
# #Inferno
# #Origen
# #Adaptaciones_cinematográficas
# #Referencias
# #Enlaces_externos
# /w/index.php?title=Dan_Brown&action=edit&section=1
# /wiki/Phillips_Exeter_Academy
# /wiki/Amherst_College
# /wiki/Gij%C3%B3n
# /wiki/Espa%C3%B1a
# /wiki/1980
# /wiki/1985
# /wiki/Universidad_de_Sevilla
# /w/index.php?title=Dalliance&action=edit&redlink=1
# /wiki/1991
# /wiki/Hollywood
# /wiki/California
# /wiki/Beverly_Hills
# /w/index.php?title=Academia_Nacional_de_Compositores&action=edit&redlink=1
# /wiki/Nuevo_Hampshire
# /w/index.php?title=Philix_Exeter_Academy&action=edit&redlink=1
# /w/index.php?title=Lincoln_Akerman_School&action=edit&redlink=1
# /wiki/1993
# /wiki/1994
# /wiki/%C3%81ngeles_y_demonios_(novela)
# /wiki/1993
# /wiki/Tahit%C3%AD
# /w/index.php?title=La_conspiraci%C3%B3n_del_juicio_final&action=edit&redlink=1
# /wiki/1991
# /wiki/Sidney_Sheldon
# /wiki/La_fortaleza_digital
# /wiki/Agencia_de_Seguridad_Nacional
# /wiki/NSA
# /wiki/Techno-thriller
# /wiki/1998
# /wiki/2000
# /wiki/%C3%81ngeles_y_demonios_(novela)
# /wiki/Robert_Langdon
# /wiki/Universidad_de_Harvard
# /wiki/Illuminati
# /wiki/Iglesia_cat%C3%B3lica
# /wiki/2001
# /wiki/La_conspiraci%C3%B3n
# /wiki/%C3%81rtico
# /w/index.php?title=SOT&action=edit&redlink=1
# /wiki/NASA
# /wiki/Superventas
# /wiki/El_c%C3%B3digo_Da_Vinci_(novela)
# /wiki/Santo_Grial
# /w/index.php?title=Dan_Brown&action=edit&section=2
# /w/index.php?title=Dan_Brown&action=edit&section=3
# /wiki/La_fortaleza_digital
# /wiki/La_conspiraci%C3%B3n
# /wiki/Robert_Langdon
# /w/index.php?title=Dan_Brown&action=edit&section=4
# /wiki/%C3%81ngeles_y_demonios_(novela)
# /wiki/%C3%81ngeles_y_demonios_(pel%C3%ADcula_de_2009)
# /wiki/El_c%C3%B3digo_Da_Vinci_(novela)
# /wiki/El_c%C3%B3digo_Da_Vinci_(pel%C3%ADcula)
# /wiki/El_s%C3%ADmbolo_perdido
# /wiki/Editorial_Planeta
# /wiki/Inferno_(novela_de_Dan_Brown)
# /wiki/Editorial_Planeta
# /wiki/Inferno_(pel%C3%ADcula_de_2016)
# /wiki/Origen_(novela_de_Dan_Brown)
# /wiki/Editorial_Planeta
# /w/index.php?title=Dan_Brown&action=edit&section=5
# /w/index.php?title=Dan_Brown&action=edit&section=6
# /w/index.php?title=Dan_Brown&action=edit&section=7
# /wiki/La_fortaleza_digital
# /wiki/Agencia_de_Seguridad_Nacional
# /w/index.php?title=Dan_Brown&action=edit&section=8
# /wiki/%C3%81ngeles_y_demonios_(novela)
# /wiki/Harvard
# /wiki/Robert_Langdon
# /wiki/Organizaci%C3%B3n_Europea_para_la_Investigaci%C3%B3n_Nuclear
# /wiki/Ciudad_del_Vaticano
# /wiki/Illuminati
# /wiki/Antimateria
# /wiki/Papable
# /wiki/C%C3%B3nclave
# /w/index.php?title=Dan_Brown&action=edit&section=9
# /wiki/La_conspiraci%C3%B3n
# /wiki/NASA
# /wiki/Plataforma_de_hielo_Milne
# /wiki/Canad%C3%A1
# /wiki/Polo_Norte
# /wiki/Vida_extraterrestre
# /w/index.php?title=Dan_Brown&action=edit&section=10
# /wiki/El_c%C3%B3digo_Da_Vinci_(novela)
# /wiki/Cr%C3%ADticas_a_%C2%ABEl_c%C3%B3digo_Da_Vinci%C2%BB
# /wiki/Robert_Langdon
# /wiki/Priorato_de_Sion
# /wiki/Leonardo_da_Vinci
# /wiki/Santo_Grial
# /wiki/Par%C3%ADs
# /wiki/Londres
# /wiki/Opus_Dei
# /w/index.php?title=Dan_Brown&action=edit&section=11
# /wiki/El_s%C3%ADmbolo_perdido
# /wiki/Francmasoner%C3%ADa
# #cite_note-1
# /wiki/Robert_Langdon
# /wiki/Instituto_de_Ciencias_No%C3%A9ticas
# /wiki/15_de_septiembre
# /wiki/2009
# /wiki/Estados_Unidos
# /wiki/29_de_octubre
# /wiki/2009
# /wiki/Espa%C3%B1a
# #cite_note-2
# /w/index.php?title=Dan_Brown&action=edit&section=12
# /wiki/Inferno_(novela_de_Dan_Brown)
# /wiki/Robert_Langdon
# /wiki/Florencia
# /wiki/Transhumanismo
# /wiki/Dante_Alighieri
# /wiki/Superpoblaci%C3%B3n
# /w/index.php?title=Dan_Brown&action=edit&section=13
# /wiki/Origen_(novela_de_Dan_Brown)
# /wiki/Robert_Langdon
# /wiki/Museo_Guggenheim_Bilbao
# /w/index.php?title=Dan_Brown&action=edit&section=14
# /wiki/Robert_Langdon
# /wiki/Ron_Howard
# /wiki/Tom_Hanks
# /wiki/El_c%C3%B3digo_Da_Vinci_(pel%C3%ADcula)
# /wiki/Ron_Howard
# /wiki/Tom_Hanks
# /wiki/Audrey_Tautou
# /wiki/Ian_McKellen
# /wiki/Alfred_Molina
# /wiki/Paul_Bettany
# /wiki/Jean_Reno
# /wiki/%C3%81ngeles_y_demonios_(pel%C3%ADcula_de_2009)
# /wiki/Ron_Howard
# /wiki/Tom_Hanks
# /wiki/Ayelet_Zurer
# /wiki/Ewan_McGregor
# /wiki/Stellan_Skarsg%C3%A5rd
# /wiki/Pierfrancesco_Favino
# /wiki/Inferno_(pel%C3%ADcula_de_2016)
# /wiki/Ron_Howard
# /wiki/Tom_Hanks
# /wiki/Felicity_Jones
# /wiki/Irrfan_Khan
# /wiki/Omar_Sy
# /wiki/Ben_Foster
# /wiki/El_s%C3%ADmbolo_perdido
# /wiki/Ron_Howard
# /wiki/Mark_Romanek
# /w/index.php?title=Dan_Brown&action=edit&section=15
# #cite_ref-1
# https://web.archive.org/web/20091031052734/http://www.publico.es/culturas/265168/dan/brown/dice/espana/descubri/opresion/religiosa/nunca
# /wiki/P%C3%BAblico_(Espa%C3%B1a)
# #cite_ref-2
# http://noticias.terra.es/GenteyCultura/2009/0421/Actualidad/Dan-Brown-regresara-en-septiembre-a-las-librerias-con-El-simbolo-perdido.aspx
# /w/index.php?title=Dan_Brown&action=edit&section=16
# /wiki/Wikimedia_Commons
# https://commons.wikimedia.org/wiki/Category:Dan_Brown
# /wiki/Wikiquote
# https://es.wikiquote.org/wiki/Dan_Brown
# http://www.danbrown.com/
# https://web.archive.org/web/20160517025132/http://www.danbrownofficial.co.uk/
# https://www.planetadelibros.com/libro-origen/254690
# /wiki/Ayuda:Control_de_autoridades
# https://www.wikidata.org/wiki/Wikidata:Main_Page
# https://www.wikidata.org/wiki/Q7345
# //www.worldcat.org/identities/containsVIAFID/102403515
# /wiki/Virtual_International_Authority_File
# https://viaf.org/viaf/102403515
# /wiki/International_Standard_Name_Identifier
# http://isni.org/isni/0000000109297080
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# http://datos.bne.es/resource/XX1660007
# /wiki/Biblioth%C3%A8que_nationale_de_France
# http://catalogue.bnf.fr/ark:/12148/cb14529449m
# http://data.bnf.fr/ark:/12148/cb14529449m
# /wiki/Biblioteca_de_Catalu%C3%B1a
# http://cantic.bnc.cat/registres/CUCId/a11978776
# /wiki/Integrated_Authority_File
# http://d-nb.info/gnd/124429548
# /wiki/Library_of_Congress_Control_Number
# http://id.loc.gov/authorities/names/n95086067
# /wiki/National_Diet_Library
# http://id.ndl.go.jp/auth/ndlna/00934700
# /wiki/National_Library_of_the_Czech_Republic
# http://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0008745&CON_LNG=ENG
# https://www.wikidata.org/wiki/Q29861311
# http://socialarchive.iath.virginia.edu/ark:/99166/w6s21ttq
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# http://www.idref.fr/07418105X
# /wiki/LIBRIS
# //libris.kb.se/auth/258460
# /wiki/BIBSYS
# http://ask.bibsys.no/ask/action/result?cmd=&kilde=biblio&cql=bs.autid+%3D+4045029&feltselect=bs.autid
# /wiki/Istituto_Centrale_per_il_Catalogo_Unico
# http://opac.sbn.it/opacsbn/opac/iccu/scheda_authority.jsp?bid=IT\ICCU\RAVV\366833
# /wiki/Open_Library
# https://openlibrary.org/works/OL39307A
# https://es.wikipedia.org/w/index.php?title=Dan_Brown&oldid=107240258
# /wiki/Especial:Categor%C3%ADas
# /wiki/Categor%C3%ADa:Hombres
# /wiki/Categor%C3%ADa:Nacidos_en_1964
# /wiki/Categor%C3%ADa:Escritores_de_Estados_Unidos
# /wiki/Categor%C3%ADa:Agn%C3%B3sticos
# /wiki/Categor%C3%ADa:Escritores_en_ingl%C3%A9s
# /wiki/Categor%C3%ADa:Escritores_de_suspenso
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_que_necesitan_referencias_adicionales
# /wiki/Categor%C3%ADa:Wikipedia:Referenciar_(a%C3%BAn_sin_clasificar)
# /wiki/Categor%C3%ADa:Personas_vivas
# /wiki/Categor%C3%ADa:Wikipedia:Control_de_autoridades_con_15_elementos
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_VIAF
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_ISNI
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_BNE
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_BNF
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_CANTIC
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_GND
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_LCCN
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_SNAC
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_SELIBR
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_BIBSYS
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_SBN
# /wiki/Categor%C3%ADa:Wikipedia:Art%C3%ADculos_con_identificadores_Open_Library
# /wiki/Categor%C3%ADa:Wikipedia:Referenciar_literatura
# /wiki/Especial:MiDiscusi%C3%B3n
# /wiki/Especial:MisContribuciones
# /w/index.php?title=Especial:Crear_una_cuenta&returnto=Dan+Brown
# /w/index.php?title=Especial:Entrar&returnto=Dan+Brown
# /wiki/Dan_Brown
# /wiki/Discusi%C3%B3n:Dan_Brown
# /wiki/Dan_Brown
# /w/index.php?title=Dan_Brown&action=edit
# /w/index.php?title=Dan_Brown&action=history
# /wiki/Wikipedia:Portada
# /wiki/Wikipedia:Portada
# /wiki/Portal:Comunidad
# /wiki/Portal:Actualidad
# /wiki/Especial:CambiosRecientes
# /wiki/Especial:P%C3%A1ginasNuevas
# /wiki/Especial:Aleatoria
# /wiki/Ayuda:Contenidos
# //donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_es.wikipedia.org&uselang=es
# /wiki/Wikipedia:Informes_de_error
# /w/index.php?title=Especial:Libro&bookcmd=book_creator&referer=Dan+Brown
# /w/index.php?title=Especial:ElectronPdf&page=Dan+Brown&action=show-download-screen
# /w/index.php?title=Dan_Brown&printable=yes
# https://commons.wikimedia.org/wiki/Category:Dan_Brown
# https://es.wikiquote.org/wiki/Dan_Brown
# /wiki/Especial:LoQueEnlazaAqu%C3%AD/Dan_Brown
# /wiki/Especial:CambiosEnEnlazadas/Dan_Brown
# //commons.wikimedia.org/wiki/Special:UploadWizard?uselang=
.wikipedia.org/wiki/Wikipedia:Texto_de_la_Licencia_Creative_Commons_Atribuci%C3%B3n-CompartirIgual_3.0_Unported
# http://creativecommons.org/licenses/by-sa/3.0/
# //wikimediafoundation.org/wiki/Terms_of_Use
# //wikimediafoundation.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://meta.wikimedia.org/wiki/Privacy_policy/es
# /wiki/Wikipedia:Acerca_de
# /wiki/Wikipedia:Limitaci%C3%B3n_general_de_responsabilidad
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://wikimediafoundation.org/wiki/Cookie_statement/es
# //es.m.wikipedia.org/w/index.php?title=Dan_Brown&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# //www.mediawiki.org/

# %% [markdown]
# ---
# # APIs Y JSON
#
#
# **API = Application programming interface
#
# Las API crean interfaces entre programas y trabajan con archivos JSON.
#
# ** JSON: Java Script Object notation.
#
# Un archivo JSON esta basado en clave:valor, como los diccionarios.

# %%
# Assign URL to variable: url
url = ('http://www.omdbapi.com/?apikey=ff21610b&t=social+network')

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()

# Print each key-value pair in json_data
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# Title:  The Social Network
# Year:  2010
# Rated:  PG-13
# Released:  01 Oct 2010
# Runtime:  120 min
# Genre:  Biography, Drama
# Director:  David Fincher
# Writer:  Aaron Sorkin (screenplay), Ben Mezrich (book)
# Actors:  Jesse Eisenberg, Rooney Mara, Bryan Barter, Dustin Fitzsimons
# Plot:  Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, but is later sued by two brothers who claimed he stole their idea, and the co-founder who was later squeezed out of the business.
# Language:  English, French
# Country:  USA
# Awards:  Won 3 Oscars. Another 165 wins & 168 nominations.
# Poster:  https://ia.media-imdb.com/images/M/MV5BMTM2ODk0NDAwMF5BMl5BanBnXkFtZTcwNTM1MDc2Mw@@._V1_SX300.jpg
# Ratings:  [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}, {'Source': 'Rotten Tomatoes', 'Value': '96%'}, {'Source': 'Metacritic', 'Value': '95/100'}]
# Metascore:  95
# imdbRating:  7.7
# imdbVotes:  537,084
# imdbID:  tt1285016
# Type:  movie
# DVD:  11 Jan 2011
# BoxOffice:  $96,400,000
# Production:  Columbia Pictures
# Website:  http://www.thesocialnetwork-movie.com/
# Response:  True

# %%
# Assign URL to variable: url
url = 'https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=Dan_Brown'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()

# Print the Wikipedia page extract
DanBrown_extract = json_data['query']['pages']
print(DanBrown_extract)
# Out:
# {'444645': {'pageid': 444645, 'ns': 0, 'title': 'Dan Brown', 'extract': '<p><b>Daniel Gerhard Brown</b> (born June 22, 1964) is an American author of thriller novels, most notably the Robert Langdon stories: <i>Angels &amp; Demons</i> (2000), <i>The Da Vinci Code</i> (2003), <i>The Lost Symbol</i> (2009), <i>Inferno</i> (2013) and <i>Origin</i> (2017). His novels are treasure hunts set in a 24-hour period, and feature the recurring themes of cryptography, keys, symbols, codes, and conspiracy theories. His books have been translated into 56 languages, and as of 2012, sold over 200 million copies. Three of them, <i>Angels &amp; Demons</i> (2000), <i>The Da Vinci Code</i> (2003) and <i>Inferno</i> (2013) have been adapted into films.</p>\n<p>Brown\'s novels that feature the lead character, Langdon, also include historical themes and Christianity as motifs, and have generated controversy. Brown states on his website that his books are not anti-Christian, though he is on a \'constant spiritual journey\' himself, and says that his book <i>The Da Vinci Code</i> is simply "an entertaining story that promotes spiritual discussion and debate" and suggests that the book may be used "as a positive catalyst for introspection and exploration of our faith".</p>\n<p></p>'}}
